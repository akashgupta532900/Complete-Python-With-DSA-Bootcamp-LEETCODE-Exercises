# %%
print(1+1)

# %% [markdown]
# Square of side 'N'

# %%
def generate_square(n):
    """
    Function to return a square pattern of '*' of side n as a list of strings.
    
    Parameters:
    n (int): The size of the square.
    
    Returns:
    list: A list of strings where each string represents a row of the square.
    """
    # Your code here
    lst=[]
    item="*"
    x=""    
    for i in range(n):
        x=""
        for j in range(n):
           x+= item          
        lst.append(x)
    return lst

generate_square(5)

# %% [markdown]
# Hollow Square of side 'N'

# %%
def generate_hollow_square(n):
    lst_hollow_square=[]
    # Your code here
    lst=[]
    item="*"
    x=""    
    for i in range(n):
        x=""
        for j in range(n):
           x+= item          
        lst.append(x)   
    t=""
    for k in range(len(lst)):
        if(k==0 or k==len(lst)-1):
            lst_hollow_square.append(lst[k])
        else:    
            t=""       
            for l in range(len(lst[k])):                
                # print(f"lst[k] {lst[k]}")
                if(l==0 or l==len(lst[k])-1):                   
                    t+="*"                    
                else:                 
                    t+=" "           
            lst_hollow_square.append(t)
      
    print (lst_hollow_square)
    
generate_hollow_square(5)

# %% [markdown]
# Rectangle Pattern

# %%
def generate_rectangle(n, m):
    """
    Function to return a rectangle pattern of '*' with length n and breadth m as a list of strings.
    
    Parameters:
    n (int): The number of rows in the rectangle.
    m (int): The number of columns in the rectangle.
    
    Returns:
    list: A list of strings where each string represents a row of the rectangle pattern.
    """
    # Your code here
    rect=[]
    for i in range(n):
        rect.append("*"*m)
    return rect

print(generate_rectangle(3, 2))

# %% [markdown]
# Right Angled Triangle

# %%
def generate_triangle(n):
    """
    Function to return a right-angled triangle of '*' of side n as a list of strings.

    Parameters:
    n (int): The height and base of the triangle.

    Returns:
    list: A list of strings where each string represents a row of the triangle.
    """

    # Your code here
    triangle = []
    for i in range(n):
        triangle.append("*"*(i+1))
    return triangle

print(generate_triangle(5))

# %% [markdown]
# Inverted Right Angled Triangle

# %%
def generate_inverted_triangle(n):
    """
    Function to return an inverted right-angled triangle of '*' of side n as a list of strings.

    Parameters:
    n (int): The height and base of the triangle.

    Returns:
    list: A list of strings where each string represents a row of the triangle.
    """
    # Your code here
    # Your code here
    inverted_triangle = []
    if (n == 1):
        inverted_triangle.append("*")
        return inverted_triangle
    for i in range(n, 0, -1):
        inverted_triangle.append("*"*(i))
    return inverted_triangle


print(generate_inverted_triangle(3))

# %% [markdown]
# Pyramid Pattern

# %%
def generate_pyramid(n):
    """
    Function to return a pyramid pattern of '*' of side n as a list of strings.
    
    Parameters:
    n (int): The number of rows in the pyramid.
    
    Returns:
    list: A list of strings where each string represents a row of the pyramid.
    """
    # Initialize an empty list to store the rows of the pyramid
    pyramid = []
      if (n == 1):
        inverted_triangle.append("*")
        return inverted_triangle
    # Loop through each row from 1 to n
    for i in range(n + 1,1 ,-1):
        # Number of stars in the current row is 2 * i - 1
        stars = '*' * (2 * i - 1)
        # Number of leading spaces to center the stars is n - i
        spaces = ' ' * (n - i)
        # Add the centered row to the list
        pyramid.append(spaces + stars + spaces)
    
    # Return the list of pyramid rows
    return pyramid
[print(len(j))for j in generate_pyramid(3)]
print(generate_pyramid(3))

# %% [markdown]
# Right Angled Triangle with Numbers

# %%
def generate_number_triangle(n):
    """
    Function to return a right-angled triangle of repeated numbers of side n as a list of strings.
    
    Parameters:
    n (int): The height of the triangle.
    
    Returns:
    list: A list of strings where each string represents a row of the triangle.
    """
    # Your code here
    result=[]
    if(n==1):
        result.append(str(1))        
        return result
         
    for i in range(1,n+1):
        result.append(str(i)*(i))
        
    return result
print(generate_number_triangle(1))

# %% [markdown]
# Floyds Triangle
# Problem Description:
#
# You are given an integer n. Your task is to return the first n rows of Floyd’s Triangle, represented as a list of strings. Floyd's Triangle is a triangular array of natural numbers where the first row contains 1, the second row contains 2 and 3, the third row contains 4, 5, and 6, and so on.

# %%
def generate_floyds_triangle(n):
    """
    Function to return the first n rows of Floyd's Triangle as a list of strings.

    Parameters:
    n (int): The number of rows in the triangle.

    Returns:
    list: A list of strings where each string represents a row of Floyd's Triangle.
    """
    # Your code here
    o = []
    counter = 1
    element = ""
    space = " "
    for i in range(1, n+1):       
        element=""
        for j in range(i):          
            element += str(counter)+space
            counter=counter+1
        o.append(element.rstrip())
    return o
print(generate_floyds_triangle(5))

# %% [markdown]
# Diamond Pattern
# Problem Description:
#
# You are given an integer n. Your task is to return a diamond pattern of '*' with n rows for the upper part (the widest row will have 2n - 1 stars), and the lower part is the mirrored version of the upper part. Each row should be centered with appropriate spaces.

# %%
def generate_diamond(n):
    """
    Function to return a diamond pattern of '*' of side n as a list of strings.

    Parameters:
    n (int): The number of rows for the upper part of the diamond.

    Returns:
    list: A list of strings where each string represents a row of the diamond.
    """   
    spaces = ""
    stars = ""
    element = ""
    result=[]
    if (n==1):
        result.append('*')
        return result
    for i in range(1, n+1):
        spaces = " "*(n-i)
        stars = "*"*(2*i-1)
        element = spaces+stars+spaces
        result.append(element)   
    
    inverted=result[n-2::-1]
    ##print(inverted)
    for i in range(len(inverted)):
        result.append(inverted[i])     
    
    return result   

# print()
generate_diamond(5)

# %% [markdown]
# Right Angled Triangle II
# Problem Description:
#
# You are given an integer n. Your task is to return a right-angled triangle pattern of '*', where each row contains stars aligned to the right. The first row has one star, the second row has two stars, and so on, until the nth row has n stars.

# %%
def generate_right_angled_triangle(n):
    """
    Function to return a right-angled triangle of '*' of side n as a list of strings.
    
    Parameters:
    n (int): The height of the triangle.
    
    Returns:
    list: A list of strings where each string represents a row of the triangle.
    """
    # Your code here
    spaces = ""
    stars = ""
    element = ""
    result=[]
    if(n==1):
        result.append("*")
        return result
    for i in range(1,n+1):
        spaces=" "*(n-i)
        stars="*"*i
        element=spaces+stars
        result.append(element)
    print(result)
    
generate_right_angled_triangle(4)

# %% [markdown]
# Hollow Right Triangle
# Problem Description:
#
# You are given an integer n. Your task is to return a hollow right-angled triangle pattern of '*', where the first and last rows contain stars, while the inner rows contain a star at the beginning and end, with spaces in between. The triangle should be right-aligned.

# %%
def generate_hollow_right_angled_triangle(n):
    """
    Function to return a hollow right-angled triangle of '*' of side n as a list of strings.
    
    Parameters:
    n (int): The height of the triangle.
    
    Returns:
    list: A list of strings where each string represents a row of the triangle.
    """
    # Your code here
    tri=[]  
    
    if(0<n<2):
        tri.append("*")      
        return tri
    else:
        tri.append("*")
        tri.append("**")
        for i in range(1,n-2):
            element= "*"+ " "*i+"*"
            tri.append(element)
        tri.append("*"*n)
        return tri

print(generate_hollow_right_angled_triangle(5))
print("*"*-1)

# %% [markdown]
# Hollow Inverted Right Triangle
# Problem Description:
#
# You are given an integer n. Your task is to return a hollow inverted right-angled triangle pattern of '*', where the first row contains n stars, while the inner rows contain a star at the beginning and end, with spaces in between. The triangle should be left-aligned.

# %%
def generate_hollow_inverted_right_angled_triangle(n):
    """
    Function to return a hollow inverted right-angled triangle of '*' of side n as a list of strings.
    
    Parameters:
    n (int): The height of the triangle.
    
    Returns:
    list: A list of strings where each string represents a row of the hollow triangle.
    """
    # Initialize an empty list to store the rows of the triangle
    triangle = []
    
    # Loop through each row from n to 1
    for i in range(n, 0, -1):
        # For the first row, just add 'n' stars
        if i == n:
            triangle.append('*' * n)
        # For the last row, add a single star
        elif i == 1:
            triangle.append('*')
        # For the intermediate rows, add a star, spaces, and another star
        else:
            # Add a star, spaces, and another star
            spaces = ' ' * (i - 2)
            triangle.append('*' + spaces + '*')
    
    # Return the list of triangle rows
    return triangle

print(generate_hollow_inverted_right_angled_triangle(5))

# %% [markdown]
# Number Pyramid Pattern
# Problem Description:
#
# You are given an integer n. Your task is to return a pyramid pattern of numbers, where each row contains increasing numbers starting from 1 up to the row number, and the pyramid is centered with leading spaces.

# %% [markdown]
# Celsius to Fahrenheit
# Problem Description:
#
# You are given a temperature in Celsius. Your task is to convert it to Fahrenheit and return the result.

# %%
def celsius_to_fahrenheit(C):
    """
    Function to convert temperature from Celsius to Fahrenheit.
    
    Parameters:
    C (float): The temperature in Celsius.
    
    Returns:
    float: The temperature in Fahrenheit.
    """
    # Your code here
    F = (9/5 * C) + 32
    return F
celsius_to_fahrenheit(25)

# %% [markdown]
# Number of Rounds of Lift
# Problem Description:
#
# You are given n, the total number of people, and capacity, the maximum number of people the lift can carry at a time. All people want to go from the ground floor to the top floor. Your task is to calculate the number of rounds the lift has to make to transport all the people to the top floor.

# %%
def calculate_lift_rounds(n, capacity):
    """
    Function to calculate the number of rounds the lift needs to cover.

    Parameters:
    n (int): Total number of people.
    capacity (int): Maximum number of people the lift can carry in one round.

    Returns:
    int: The number of rounds required to transport all people to the top floor.
    """
    # Your code here
    count = 0
    while (n > 0):
        count = count+1
        n = n-capacity
        print(f"n {n}")
    return count
print(calculate_lift_rounds(7, 4))

# %% [markdown]
# Remove Duplicate in a List

# %%
def remove_duplicates(lst):
    result=[]
    # Your code goes here
    for i in range(len(lst)):
        if (lst[i] != -1):
            for j in range(i+1, len(lst)):
                if (lst[i] == lst[j]):
                    lst[j] = -1
            result.append(lst[i])            
    return result

print(remove_duplicates([1, 2, 2, 3, 4, 4, 5]))
print(remove_duplicates([4, 5, 5, 4, 6, 7]))
print(remove_duplicates([1,1,1,1,1]))

# %% [markdown]
# Check if all elements in a list are Unique

# %%
def check_unique(lst):
    for i in range(len(lst)):
        if (lst[i] != -1):
            for j in range(i+1, len(lst)):
                if (lst[i] == lst[j]):
                   return False
    return True

print(check_unique([1, 2, 3, 4, 5]))
print(check_unique([1, 2, 3, 3, 4, 5]))

# %% [markdown]
# Program to Reverse a List

# %%
def reverse_list(lst):
    # Your code goes here
    j=len(lst)-1
    i=0
    while(i<j):
        temp = lst[i]
        lst[i] = lst[j]
        lst[j] = temp
        j=j-1
        i=i+1  
    return lst

print(reverse_list([1, 2, 3, 4, 5]))

# %% [markdown]
# Count Number of Odd and Even Elements in a List

# %%
def count_even_odd(lst):  
    
    even_count=0
    odd_count=0
    # Your code goes here
    for i in range(len(lst)):
        if (lst[i] % 2 == 0):
            even_count = even_count+1
        else:
            odd_count = odd_count+1
    result=(even_count,odd_count)
    return result
            
print(count_even_odd([1, 2, 3, 4, 5]))

# %% [markdown]
# Maximum difference between two consecutive elements in a list.

# %%
def max_consecutive_difference(lst):
    # Your code goes here
    max = 0
    diff = 0
    for i in range(len(lst)-1):
        diff = abs( lst[i]-lst[i+1])
        if (diff > max):
            max = diff
    return max

print(max_consecutive_difference([1, 7, 3, 10, 5]))
print(max_consecutive_difference([10, 11, 15, 3]))

# %% [markdown]
# Merge two Sorted List

# %%
def merge_two_sorted_lists(list1, list2):
    # Your code goes here
    i = 0
    j = 0
    ms = []
    while (i < len(list1) and j < len(list2)):
        if (list1[i] < list2[j]):
            ms.append(list1[i])
            i = i+1
        else:
            ms.append(list2[j])
            j = j+1
        
    while(i<len(list1)):
        ms.append(list1[i])
        i=i+1
    while(j<len(list2)):
        ms.append(list2[j])
        j=j+1        
    return ms


print(merge_two_sorted_lists([1, 3, 5], [2, 4, 6]))
print(merge_two_sorted_lists([1, 4, 7], [2, 3, 5, 8]))

# %% [markdown]
# Rotate a List
# Rotate a List (Without Slicing)

# %%
def rotate_list(lst, k):
    last=0
    # if lst is not list:
    #     return []
    n=len(lst)
    k = k%n
    
    
    for i in range(k):
        last=lst[n-1]
        
        for j in range(n-1,0,-1):
            lst[j]=lst[j-1]
        lst[0]=last
        
    print(lst)

rotate_list([1, 2, 3, 4, 5],2)

# %% [markdown]
# Merge 2 List into Dictionary

# %%
def merge_lists_to_dictionary(keys, values):
    # Your code goes here
    i = 0

    dic = {}
    if (len(keys) != len(values)):
        return False
    while (i < len(keys)):
        dic[keys[i]] = values[i]
        i = i+1

    return dic


print(merge_lists_to_dictionary(['a', 'b', 'c'], [1, 2, 3]))

# %% [markdown]
# Merge Multiple Dictionaries
# Merge Three Dictionaries

# %%
def merge_three_dictionaries(dict1, dict2, dict3):
    # Your code goes here
    merged={}
    for key,value in dict1.items():
        merged[key]=value
    for key,value in dict2.items():
        merged[key]=value
    for key,value in dict3.items():
        merged[key]=value
        
    return merged

print(merge_three_dictionaries({'a': 1, 'b': 2},{'c': 3, 'd': 4}, {'e': 5, 'f': 6}))

# %% [markdown]
# Words Frequency in a Sentence
# Count Word Frequency

# %%
def count_word_frequency(sentence):
    result={}
    # Your code goes here
    
    if(sentence==""):        
        return result
    words = sentence.split(" ")    
    for word in words:              
        if word in result.keys():            
            result[word]= result[word]+1
        else:
            result[word]=1
        
    
    return result

# print(count_word_frequency("hello world hello"))
# print(count_word_frequency("the quick brown fox jumps over the lazy dog"))
print(count_word_frequency(""))

# %% [markdown]
# Palindromic Tuple
# Check if Tuple is Palindromic

# %%
def is_palindromic_tuple(tup):
    # Your code goes here
    i=0
    j=len(tup)-1
    while(i<j):
        if(tup[i]!=tup[j]):            
            return False
        i=i+1
        j=j-1
    return True
        
##print(is_palindromic_tuple((1, 2, 3, 2, 1)))

print(is_palindromic_tuple(('a',)))

# %% [markdown]
# Merge Dictionaries with Common Keys

# %%
def merge_dicts_with_overlapping_keys(dicts):
    # Your code goes here
    if (len(dicts) < 1):
        return {}
    result = dicts[0].copy()

    for dic in range(1, len(dicts)):
        for key in dicts[dic].keys():
            if key in result:
                result[key] += dicts[dic][key]
            else:
                result[key] = dicts[dic][key]
    return result


merge_dicts_with_overlapping_keys(
    [{'a': 1, 'b': 2}, {'b': 3, 'c': 4}, {'c': 5, 'd': 6}])

# %% [markdown]
# Check if List is Subset of another List

# %%
def is_subset(lst1, lst2):
    result= False
    for i in range(len(lst1)):
        for j in range(len(lst2)):
            if(lst1[i]==lst2[j]):
                continue
        result=True       
    return result    
                
            
print(is_subset([1, 2, 3], [1, 2, 3, 4, 5]))
print(is_subset([1, 6], [1, 2, 3, 4, 5]))

# %% [markdown]
# Sum of N Even Natural Numbers

# %%
def sum_of_even_numbers(n):
    """
    Function to return the sum of the first n even natural numbers.

    Parameters:
    n (int): The number of even numbers to sum.

    Returns:
    int: The sum of the first n even natural numbers.
    """
    # Your code here
    sum = 0
    for i in range(2*n+1):
        if (i % 2 == 0):
            sum = sum+i
    return sum

sum_of_even_numbers(2)

# %% [markdown]
# Check for Even Number

# %%
def is_even(n):
    """
    Function to check if a number is even.
    
    Parameters:
    n (int): The number to check.
    
    Returns:
    bool: True if n is even, False otherwise.
    """
    # Your code here

# %% [markdown]
# Check for Prime Number

# %%
def is_prime(n):
    """
    Function to check if a number is prime.
    
    Parameters:
    n (int): The number to check.
    
    Returns:
    bool: True if n is prime, False otherwise.
    """
    # Your code here
    
    if (n % 2 == 0):
        return False
    else:
        return True

# %% [markdown]
# Valid Perfect Square

# %%
def is_perfect_square(num):
    """
    Function to check if a number is a perfect square.
    
    Parameters:
    num (int): The number to check.
    
    Returns:
    bool: True if num is a perfect square, False otherwise.
    """
    # Your code here
    (num)

# %% [markdown]
# Decimal to Binary
# Problem Description:

# %%
def int_to_binary(n):
    """
    Function to convert an integer to its binary representation.
    
    Parameters:
    n (int): The integer to convert.
    
    Returns:
    str: The binary representation of the integer.
    """
    # Your code her
    output=n | 0
    
    print(bin(n))
    
int_to_binary(5)

# %% [markdown]
# Binary to Decimal

# %%
def binary_to_decimal(binary_str):
    """
    Function to convert a binary string to its decimal integer representation.
    
    Parameters:
    binary_str (str): The binary string to convert.
    
    Returns:
    int: The decimal representation of the binary string.
    """
    # Your code here
    sum=0
    
    for c in binary_str:
        sum+=2**int(c)
    return sum
        
print(binary_to_decimal("1011"))

# %% [markdown]
# GCD of Two Numbers

# %%
def gcd(n, m):
    """
    Function to find the GCD of two integers without using built-in functions and recursion.

    Parameters:
    n (int): The first integer.
    m (int): The second integer.

    Returns:
    int: The GCD of n and m.
    """
    # Your code here
    smallest_number = 0
    largest_number = 0
    if (n < m):
        smallest_number = n
        largest_number = m
    else:
        smallest_number = m
        largest_number = n

    common_factor = 0

    for i in range(1, smallest_number+1):
        if (smallest_number % i == 0):
            if (largest_number % i == 0):
                if (i > common_factor):
                    common_factor = i
    return common_factor


print(gcd(56, 98))

# %% [markdown]
# Reverse a string

# %%
def reverse_string(s):
    """
    Function to return the reversed version of the input string.
    
    Parameters:
    s (str): The input string to be reversed.
    
    Returns:
    str: The reversed string.
    """
    # Your code here
    reverse_string=""
    for i in range(1,len(s)+1):
        reverse_string+=s[len(s)-i]
        
    return reverse_string


print(reverse_string("Hello"))

# %%
def count_vowels(s):
    """
    Function to count the number of vowels in the input string.
    
    Parameters:
    s (str): The input string to check for vowels.
    
    Returns:
    int: The count of vowels in the input string.
    """
    # Your code here
    count=0
    s=s.lower()
    for i in range(len(s)):
        if(s[i]=="a"or s[i]=="e" or s[i]=="i" or s[i]=="o" or s[i]=="u"):
            count=count+1;
            
    return count

# %% [markdown]
# Check for same strings

# %%
def are_equal_strings(s, t):
    """
    Function to check if two strings are equal without using built-in functions.

    Parameters:
    s (str): The first string.
    t (str): The second string.

    Returns:
    bool: True if the strings are equal, False otherwise.
    """
    # Your code here
    if (len(s) ==0 and  len(t)==0):
        return True
    if (len(s) != len(t)):
        return False
    i=0
    j=0
    result=False
    while(i<len(s)):
        if(s[i]==t[j]):
            result=True
        else:
            result=False
        i=i+1
        j=j+1
        
    return result

print(are_equal_strings("", ""))

# %% [markdown]
# Check Palindrome

# %%
def is_palindrome(s):
    """
    Function to check if the input string is a palindrome.
    
    Parameters:
    s (str): The input string to check.
    
    Returns:
    bool: True if the string is a palindrome, False otherwise.
    """
    # Your code here
    if(len(s)==0):
        return True
    s=s.replace(" ","").lower()
    print(s)
    i=0
    j=len(s)-1
    while(i<j):
        if(s[i]!=s[j]):
            return False
        i=i+1
        j=j-1
    return True

print(is_palindrome("Hello, World!"))

# %%
def count_words(s):
    """
    Function to count the number of words in the input string.

    Parameters:
    s (str): The input string to check for words.

    Returns:
    int: The count of words in the input string.
    """
    # Your code here
    if (len(s) == 0):
        return 0

    for i in range(len(s)):
        if (s[i] == " " and s[i+1] == " "):
            s[i]+= " "
    words = s.split(" ")
    return len(words)


print(count_words("Hello,  World!"))

# %% [markdown]
# Remove Duplicates in a string

# %%
def remove_duplicates(s):
    """
    Function to remove duplicate characters from the input string.

    Parameters:
    s (str): The input string from which duplicates need to be removed.

    Returns:
    str: The modified string with duplicates removed.
    """
    # Your code here
    if (len(s) == 0):
        return ""
    output = ""

    for i in range(len(s)):
        if s[i] not in output:
            output += s[i]
    return output


remove_duplicates("Hello, World")

# %% [markdown]
# Count consonants in a string

# %%
def count_consonants(s):
    """
    Function to count the number of consonants in the input string.

    Parameters:
    s (str): The input string to check for consonants.

    Returns:
    int: The count of consonants in the input string.
    """
    # Your code here
    count=0
    s= "".join(char for char in s if char.isalnum()).lower()
    for char in s:
        if(char!="a" and char!="e" and char!="i" and char!="o" and char !="u"):
            count=count+1
    return count    
            
print(count_consonants("hello"))

# %% [markdown]
# Check for anagrams

# %%
def is_anagram(s, t):
    """
    Function to check if t is an anagram of s.
    
    Parameters:
    s (str): The first input string.
    t (str): The second input string.
    
    Returns:
    bool: True if t is an anagram of s, False otherwise.
    """
    # Your code here

    for char in s:          
        if char in t:
            pass
        else:
            return False
    return True

print(is_anagram("rat", "cat"))

# %% [markdown]
# Check Subsequence
# Example:
#
# Input: s = "abcde", t = "ace"
# Output: True
#
# Input: s = "abcde", t = "aec"
# Output: False

# %%
def is_subsequence(s, t):
    """
    Function to check if t is a subsequence of s.

    Parameters:
    s (str): The original string.
    t (str): The target subsequence string.

    Returns:
    bool: True if t is a subsequence of s, False otherwise.
    """
    # Your code here
    i, j = 0,0

    while (i < len(s) and j < len(t)):
        if (s[i] == t[j]):
            j += 1
        i += 1
    return j == len(t)


print(is_subsequence("abcde", "aec"))

# %% [markdown]
# Check for Substring
# Example:
#
# Input: s = "hello world", t = "world"
# Output: True
#
# Input: s = "hello world", t = "worlds"
# Output: False

# %%
def is_substring(s, t):
    """
    Function to check if string t is a substring of string s without using built-in functions and recursion.

    Parameters:
    s (str): The main string.
    t (str): The string to check as a substring.

    Returns:
    bool: True if t is a substring of s, False otherwise.
    """
    # Your code here
    i, j = 0, 0
    while (i < len(s) and j < len(t)):
        print(f"s[i]: {s[i]} and t[j]: {t[j]}")
        if (s[i] == t[j]):
            j +=1
        i +=1        
    return j == len(t)

print(is_substring("hello world", "abcd"))

# %% [markdown]
# Length of the Longest Word

# %%
def longest_word_length(s):
    """
    Function to find the length of the longest word in a string without using built-in functions.

    Parameters:
    s (str): The input string.

    Returns:
    int: The length of the longest word.
    """
    # Your code here
    
    if(len(s)<=0):
        return ""
    max = 0
    count = 0
    for char in s:
        # print(char)
        if (char != " "):
            count = count + 1
        else:
            count = 0
        if (max < count):
            max=count
    return max


print(longest_word_length("The quick browns fox jumps over the lazy dog"))

# %% [markdown]
# Linear Search Algorithm

# %%
def linear_search(arr, target):
    # TODO: Implement this function
    for index in range(len(arr)):
        if(arr[index]==target):
            return index
        
    return -1

# %% [markdown]
# Code Bubble Sort

# %%
def bubble_sort(lst):
    # Your code goes here
    n = len(lst)

    for passes in range(n):
        for j in range(n-1-passes):
             if(lst[j] > lst[j+1]):
                lst[j], lst[j+1] = lst[j+1], lst[j]
            
    return lst

print(bubble_sort([64, 34, 25, 12, 22, 11, 90]))

# %% [markdown]
# Selection Sort

# %%
def selection_sort(lst):
    # Your code goes here
    x = 0
    n = len(lst)
    # print(find_min(lst))
    # first_pass = swap(lst, find_min(lst)[0], find_min(lst)[1])

    for i in range(n):
        index = find_min_index(lst, i)
        lst = swap(lst, i,  index)
        print(lst)
    return lst


def find_min_index(lst, index):
    min = lst[index]
    min_index = 0
    for i in range(index, len(lst)):
        if (lst[i] < min):
            min = lst[i]
            min_index = i
    if (min_index == 0):
        min_index = index
    return min_index


def swap(lst, current_index, index):
    lst[current_index], lst[index] = lst[index], lst[current_index]
    return lst


selection_sort([64, 25, 12, 22, 11])
selection_sort([29, 10, 14, 37, 13])

# %% [markdown]
# Insertion Sort

# %%
def insertion_sort(arr):
    n = len(arr)

    for i in range(1, n):
        for j in range(i,0,-1):
            if (arr[j-1] > arr[j]):
                arr[j-1], arr[j] = arr[j], arr[j-1]
    return arr


print(insertion_sort([12, 11, 13, 5, 6]))
print(insertion_sort([31, 41, 59, 26, 41, 58]))
print(insertion_sort([31]))
print(insertion_sort([5,4,3,2,1]))

# %% [markdown]
# Insertion Sort using shifting

# %%
def insertion_sort(arr):
    n = len(arr)

    for i in range(1, n):
        currentcard = arr[i]
        correctPosition = i-1

        while correctPosition >= 0:
            if (arr[correctPosition] < currentcard):
                break
            else:
                arr[correctPosition+1] = arr[correctPosition]
                correctPosition = correctPosition-1
            arr[correctPosition+1] = currentcard

    return arr


print(insertion_sort([12, 11, 13, 5, 6]))

# %% [markdown]
# Count negative numbers in a sorted matrix

# %%
def countNegatives(grid):
    # Implement your solution here
    print(len(grid))
    print(len(grid[0]))
    print(grid[0][0])
    negative_counter=0
    for i in range(len(grid)):
        for j in range(len(grid[i])):
             if(grid[i][j]<0):
                  negative_counter=negative_counter+1
     
    return negative_counter
    


print(countNegatives([[4, 3, 2, 1], [3, 2, 1, -1], [1, 1, -1, -2], [-1, -1, -2, -3]]))
print(countNegatives([[3, 2], [1, 0]]))

# %% [markdown]
# Find smallest letter greater than target

# %%
def next_greatest_letter(letters, target):
    """
    Return the smallest character in letters that is lexicographically greater than target.

    Parameters:
    letters (List[char]): Sorted array of characters.
    target (char): The target character.

    Returns:
    char: The smallest character greater than target, or the first character if no such character exists.
    """
    # Implement the function logic
    n = len(letters)
    mid = 0
    low = 0
    high = n-1
    while (low <= high):
        mid = (low+high)//2
        if (ord(letters[mid]) > ord(target)):
            high = mid-1
        elif (ord(letters[mid]) == ord(target)):
            return letters[mid+1]
        else:
            low = mid+1

    if (mid <= 0 or mid >= len(letters)-1):
        return letters[0]

print(next_greatest_letter(['c', 'f', 'j'], 'a'))

# %% [markdown]
# Find First and Last Position of Element in Sorted Array

# %%
def searchRange(nums, target):
    # Implement your solution here
    n = len(nums)
    mid = 0
    low = 0
    high = n-1
    lst = []

    while (low <= high):
        mid = (low+high)//2
        if (nums[mid] == target):
            lst.insert(0, mid)
            return lst
        elif (target < nums[mid]):
            high = mid-1
        else:
            low = mid+1

    return [-1, -1]


print(searchRange([5, 7, 7, 8, 8, 10], 8))
print(searchRange([5, 7, 7, 8, 8, 10], 6))

# %%
def searchRange(nums, target):
    """
    Find the starting and ending position of a given target value in a sorted array.
    Use binary search to find both the first and last occurrence of the target.
    """
    def findFirst(nums, target):
        """
        Find the first occurrence of the target using binary search.
        """
        left, right = 0, len(nums) - 1
        result = -1
        while left <= right:
            mid = (left + right) // 2
            if nums[mid] == target:
                result = mid
                right = mid - 1 # keep searching LEFT
            elif nums[mid] < target:
                left = mid + 1
            else:
                right = mid - 1
        return result
 
    def findLast(nums, target):
        """
        Find the last occurrence of the target using binary search.
        """
        left, right = 0, len(nums) - 1
        result = -1
        while left <= right:
            mid = (left + right) // 2
            if nums[mid] == target:
                result = mid
                left = mid + 1  # keep searching RIGHT
            elif nums[mid] < target:
                left = mid + 1
            else:
                right = mid - 1
        return result
 
    start = findFirst(nums, target)
    end = findLast(nums, target)
 
    return [start, end]

print(searchRange([5, 7, 7, 8, 8, 10], 8))
print(searchRange([5, 7, 7, 8, 8, 10], 6))

# %%
def binary_search_range_first(nums, target):
    low = 0
    mid = -1
    high = len(nums)-1
    result=-1

    while (low <= high):
        mid = (low+high)//2
        if (nums[mid] == target):
            result=mid
            high = mid-1  # keep searching left
        elif (target > nums[mid]):
            low = mid+1
        else:
            high = mid-1
    return result

def binary_search_range_last(nums, target):
    low = 0
    mid = 0
    result=-1
    high = len(nums)-1

    while (low <= high):
        mid = (low+high)//2
        if (nums[mid] == target):
            result=mid
            low=mid+1  # keep searching Right
        elif (target > nums[mid]):
            low = mid+1
        else:
            high = mid-1
    return result


start=binary_search_range_first(nums, target)
end=binary_search_range_last(nums, target)

return [start,end]
nums = [1, 3, 5, 7]
target = 2
start=binary_search_range_first(nums, target)
end=binary_search_range_last(nums, target)

print([start,end])

nums = [2, 2, 2, 2]
target = 2
start=binary_search_range_first(nums, target)
end=binary_search_range_last(nums, target)

print([start,end])

# %% [markdown]
# Minimum in Rotated Sorted Array

# %%
def findMin(nums):
    # Implement your solution here
    low = 0
    high = len(nums)-1
    while (low < high):
        mid = (low+high)//2        
        if (nums[mid] > nums[high]):
            low = mid+1       
        else:
            high=mid
    return nums[low]

# %% [markdown]
# Search in Rotated Sorted Array

# %%
def search(nums, target):
    # Implement your solution here
    low = 0
    high = len(nums)-1
    mid = 0

    while (low < high):
        mid = (low+high)//2
        if (nums[mid] == target):
            return mid
        if(nums[mid]>=nums[low]):
           high=mid-1
        else:
            low=mid+1            
        
    return -1

print(search([4, 5, 6, 7, 0, 1, 2], 0))

# %% [markdown]
# Koko Eating Bananas
# Asked in:
#
# Google
# Amazon
#
# 🧩 Problem Description
#
# Koko loves bananas. There are n piles of bananas, where the i-th pile has piles[i] bananas.
#
# She eats at a constant speed of k bananas per hour.
#
# 👉 Each hour:
#
# She picks one pile
# Eats k bananas
# If pile has less than k → she eats all and moves on next hour
# 🎯 Goal
#
# Find the minimum integer k such that she can eat all bananas within h hours.
#
# Example
# piles = [3,6,7,11]
# h = 8
#
# Output:
#
# 4

# %%
def find_k(piles, h):
    low = 1
    high = max(piles)
    total_hrs = 0
    answer = high
    print(f"low: {low} high: {high}")

    while (low <= high):
        mid = (low+high)//2

        total_hrs = 0
        for pile in piles:
            # print(f"{(pile+mid-1)}")
            # print(f"{(pile+mid-1)//mid}")
            total_hrs += (pile+mid-1)//mid
            # print(f" {total_hrs}")
        if (total_hrs <= h):
            answer = mid
            high = mid-1
        else:
            low = mid+1

    return answer


piles = [3, 6, 7, 11]
h = 8
find_k(piles, h)

# %% [markdown]
# Find First Occurrence of Target
# nums = [1,2,2,2,3,4]
# target = 2
#
# Output: 1

# %%
def find_first_occurence(nums, target):
    low = 0
    high = len(nums)-1
    mid = 0
    answer = -1

    while (low <= high):
        mid = (low+high)//2
        if (target == nums[mid]):
            answer = mid
            high = mid-1
        elif (target < nums[mid]):
            high = mid-1
        else:
            low = mid+1

    return answer
print(find_first_occurence([1,2,2,2,3,4],2))

# %%
def find_last_occurrence(nums, target):
    low = 0
    high = len(nums)-1
    mid = 0
    answer = -1

    while (low <= high):
        mid = (low+high)//2
        if (target == nums[mid]):
            answer = mid
            low = mid+1
        elif (target < nums[mid]):
            high = mid-1
        else:
            low = mid+1

    return answer

print(find_last_occurrence([1,2,2,2,3,4],2))

# %% [markdown]
# 4. Count Occurrences
#
# Find how many times target appears.
#
# nums = [1,2,2,2,3,4], target = 2

# %%
def count_occurences(nums, target, find_first):
    low = 0
    high = len(nums)-1
    mid = 0
    result = -1
    

    while (low <= high):
        mid = (low+high)//2
        if (target == nums[mid]):            
            result = mid
            if find_first:
                high = mid-1
            else:
                low = mid+1
        elif (target > nums[mid]):
            low = mid+1
        else:
            high = mid-1
            
    return result;


nums = [1,2,2,2,3,4]
target = 2

def first_and_last(nums, target):
    lst= [
        count_occurences(nums, target, True),
        count_occurences(nums, target, False)
    ]
    count=lst[1]-lst[0]+1
    return count

print(first_and_last(nums, target))

# %% [markdown]
# 🧠 Problem Restatement
#
# Given:
#
# x = 37
#
# You must find:
#
# the largest integer k such that k² ≤ x

# %%
def sqrt(x):
    low = 0
    high = x
    mid = 0
    answer = high
    while (low <= high):
        mid = (low+high)//2

        if (mid**2 <= x):
            answer = mid
            low = mid+1
        else:
            high = mid-1

    return answer


print(sqrt(50))

# %% [markdown]
# Search Insert Position Find index where target should be inserted.
# nums = [1,3,5,6], target = 5
#
# 🧠 Problem Understanding
#
# You are given:
#
# nums = [1,3,5,6]
# target = 5
#
# 👉 You must return:
#
# The index where target exists OR where it should be inserted

# %%
def find_postion_insert(nums, target):
    low = 0
    high = len(nums)-1
    mid = 0
    answer = 0

    while (low <= high):
        mid = (low+high)//2

        if (target == nums[mid]):
            return mid
        elif (target < nums[mid]):
            high = mid-1
        else:
            low = mid+1
    return low


find_postion_insert([1, 3, 5, 6], 4)

# %% [markdown]
# 7. Peak Element Find index of peak element.
# text id="b7"
# nums = [1,2,3,1]
#
# 🧠 Problem: Peak Element
# nums = [1,2,3,1]
#
# A peak element is:
#
# An element that is greater than its neighbors
#
# So:
#
# 3 is a peak (because 2 < 3 > 1)
#
# 👉 Output: index 2

# %%
def find_peak_element(nums):
     low = 0
     high = len(nums)-1
     mid = 0
     while(low<high):
         mid=(low+high)//2
         
         if(nums[mid+1]>nums[mid]):
             low=mid+1
         else:
             high=mid
     
     return low
 
nums = [1,2,3,1]
print(find_peak_element(nums))

# %% [markdown]
# ## 8. Minimum in Rotated Array
#
# Find minimum element.
#
# ```text id="b8"
# nums = [4,5,6,7,0,1,2]

# %%
def find_min(nums):
    low = 0
    high = len(nums)-1
    mid = 0
    while (low < high):
        mid = (low+high)//2
        if (nums[mid] > nums[high]):
            low = mid+1
        else:
            high = mid            
    return nums[low]

print(find_min([4,5,6,7,0,1,2]))

# %% [markdown]
# ## 9. Search in Rotated Array
#
# Find target index.
#
# ```text id="b9"
# nums = [4,5,6,7,0,1,2], target = 0
# ```

# %%
def search(a, target):
    low = 0
    high = len(a)-1
    mid = 0
    while (low <= high):
        mid = (low+high)//2

        if (a[mid] > a[high]):
            if (a[high] < target < a[mid]):
                low = mid+1
            else:
                high = mid-1
        else:
            if (a[low] < target < a[mid]):
                high = mid-1
            else:
                low = mid+1

        return low

nums = [4,5,6,7,0,1,2]
target = 0
print(search(nums,target))

# %% [markdown]
# 🌸 Problem Understanding
#
# You are given:
#
# bloomDay = [1,10,3,10,2]
# m = 3
# k = 1
# What it means:
# Each number = day when a flower blooms
# You need to make:
# m = 3 bouquets
# each bouquet needs k = 1 adjacent flower

# %%
def min_days(days, m, k):
    # from Chatgpt
    if m * k > len(days):
        return -1

    low = min(days)
    high = max(days)
    answer = -1

    while low <= high:
        mid = (low + high) // 2

        # count bouquets
        bouquets = 0
        flowers = 0

        for d in days:
            if d <= mid:
                flowers += 1
                if flowers == k:
                    bouquets += 1
                    flowers = 0
            else:
                flowers = 0

        if bouquets >= m:
            answer = mid
            high = mid - 1
        else:
            low = mid + 1

    return answer
days =[1,10,3,10,2]
m = 3
k = 1
print(min_days(days, m, k))

# %%
def min_days(days, m, k):
    low = min(days)
    high = max(days)
    result = -1

    while low <= high:
        mid = (low+high)//2

        flowers = 0
        bouquet = 0
        for d in days:
            if mid >= d:
                flowers += 1
                if (flowers == k):
                    bouquet += 1
                    flowers = 0
            else:
                flowers = 0
                
        if(bouquet>=m):
            result =mid
            high=mid-1
        else:
            low=mid+1
    return result

days =[1,10,3,10,2]
m = 3
k = 1
print(min_days(days, m, k))

# %% [markdown]
# Maximum Element in a List.
# Asked in Companies:
#
# Google
#
# Amazon
#
# Microsoft
#
# Facebook

# %%
def find_max_element(lst):
    """
    Function to find the maximum element in a list.
    :param lst: List[int] -> List of integers
    :return: int -> The maximum element in the list
    """
    # TODO: Implement this function

    max = lst[0]
    for i in lst:
        if (i > max):
            max = i
    return max

lst=[3, 5, 2, 9, 6]
find_max_element(lst)

# %% [markdown]
# Sum of Elements in a List
# Asked in Companies:
#
# Google
#
# Amazon
#
# Microsoft
#
# Facebook

# %%
def sum_of_elements(lst):
    """
    Function to find the sum of all elements in the list.
    :param lst: List[int] -> List of integers
    :return: int -> The sum of all elements in the list
    """
    # TODO: Implement this function
    sum=0
    for i in lst:
        sum+=i
    return sum

# %% [markdown]
# Palindrome List
# Asked in Companies:
#
# Google
#
# Amazon
#
# Microsoft
#
# Facebook

# %%
def is_palindrome(lst):
    """
    Function to check if a list is a palindrome.
    :param lst: List[int] -> List of integers
    :return: bool -> True if the list is a palindrome, False otherwise
    """
    # TODO: Implement this function
    i=0;
    j=len(lst)-1
    result=True
    while(i<j):
        if(lst[i]!=lst[j]):
            result=False
        i+=1
        j-=1
    return result

lst = [1]
print(is_palindrome(lst))

# %% [markdown]
# Reverse a List
# Asked in Companies:
#
# Google
#
# Amazon
#
# Microsoft
#
# Apple

# %%
def reverse_list(lst):
    """
    Function to reverse the order of elements in a list.
    :param lst: List[int] -> List of integers
    :return: List[int] -> The list with elements in reversed order
    """
    i = 0
    j = len(lst)-1
    result = 0
    temp = 0
    while (i < j):
        temp = lst[i]
        lst[i] = lst[j]
        lst[j] = temp
        i+=1
        j-=1
    return lst

lst = [9]
print(reverse_list(lst))

# %% [markdown]
# Rotate List
# Asked in Companies:
#
# Google
#
# Amazon
#
# Microsoft
#
# Facebook

# %%
def rotate_left(ARR, D):
    """
    Function to rotate the list to the left by D positions.
    :param ARR: List[int] -> The list of integers
    :param D: int -> The number of positions to rotate
    :return: List[int] -> The list after rotation
    """
    # TODO: Implement this function
    count = 0
    last_element = 0
    n = len(ARR)
    for i in range(D):
        last_element = ARR[0]
        for i in range(1, n):
            ARR[i-1] = ARR[i]
        ARR[len(ARR)-1] = last_element
    return ARR

ARR = [10, 20, 30, 40, 50]
D = 3
print(rotate_left(ARR, D))

# %% [markdown]
# Plus One in the Number
# Asked in Companies:
#
# Google
#
# Amazon
#
# Microsoft
#
# Facebook
#
# Description:
# You are given a large integer represented as an integer array digits, where each digits[i] is the i-th digit of the integer. The digits are ordered from most significant to least significant in left-to-right order. The large integer does not contain any leading zeroes.
#
# Write a function to increment the large integer by one and return the resulting array of digits.

# %%
def plus_one(digits):
    """
    Function to increment a large integer represented as a list of digits by one.
    :param digits: List[int] -> List of digits representing the large integer
    :return: List[int] -> The list representing the integer after incrementing
    """
    # Start from the last digit
    n = len(digits)
    for i in range(n - 1, -1, -1):
        if digits[i] < 9:
            digits[i] += 1
            return digits
        digits[i] = 0
    
    # If all digits are 9, the result will be a list of zeros with a 1 at the beginning
    return [1] + digits
 
# Helper function to display the result (for debugging)
def display_result(digits):
    print(plus_one(digits))
 
# Example usage (can be removed)
digits = [9,9,9]
display_result(digits)  # Output should be [1, 0, 0, 0]

# %% [markdown]
# Missing Number
# Asked in Companies:
#
# Google
#
# Microsoft
#
# Amazon
#
# Facebook
#
# Description:
# Given an array nums containing n distinct numbers in the range [0, n], return the only number in the range that is missing from the array.

# %%
def missing_number(nums):
    n = len(nums)
    xor = 0

    for i in range(n + 1):
        xor ^= i

    for num in nums:
        xor ^= num

    return xor
        
missing_number([3, 0, 1])

# %% [markdown]
# Is Array Sorted?
# Asked in Companies:
#
# Google
#
# Microsoft
#
# Amazon
#
# Facebook
#
#
#
# Description:
# Write a function that checks whether the given array is sorted in non-decreasing order. The array is considered sorted if every element is less than or equal to the next elemen

# %%
def is_sorted(arr):
    """
    Function to check if the given array is sorted in non-decreasing order.
    :param arr: List[int] -> A list of integers
    :return: bool -> True if the array is sorted, False otherwise
    """
    n = len(arr)   

    for i in range(1, n-1):
        if (arr[i] > arr[i+1]):
            return False
    return True


print(is_sorted([5, 4, 3, 2, 1]))
print(is_sorted([1, 3, 2, 4, 5]))
print(is_sorted([1, 2, 2, 3]))
print(is_sorted([]))

# %% [markdown]
# Move Zeroes
# Asked in Companies:
#
# Google
#
# Amazon
#
# Microsoft
#
# Facebook
# Description:
# Given an integer array nums, write a function to move all 0s to the end of the array while maintaining the relative order of the non-zero elements.

# %%
def move_zeroes(nums):
    """
    Function to move all 0's to the end of the array while maintaining the order of non-zero elements.
    :param nums: List[int] -> A list of integers
    :return: None -> The list is modified in place
    """
    # TODO: Implement this function
    n = len(nums)
    zero = 0
    for i in range(n):
        if (nums[i] == 0):
            zero = nums[i]

            for j in range(i+1, n):
                nums[j-1] = nums[j]
            nums[len(nums)-1] = zero
            print(nums)
            
print(move_zeroes([0, 1, 0, 3, 12]))
# Out:
# [1, 0, 3, 12, 0]
# [1, 3, 12, 0, 0]
# [1, 3, 12, 0, 0]
# [1, 3, 12, 0, 0]
# None

# %% [markdown]
# Move Zeroes
# Asked in Companies:
#
# Google
#
# Amazon
#
# Microsoft
#
# Facebook
#
# Description:
# Given an integer array nums, write a function to move all 0s to the end of the array while maintaining the relative order of the non-zero elements.

# %%
def move_zeroes(nums):
    """
    Function to move all 0's to the end of the array while maintaining the order of non-zero elements.
    :param nums: List[int] -> A list of integers
    :return: None -> The list is modified in place
    """
    # TODO: Implement this function
    nums_position = 0

    for num in nums:
        if (num != 0):
            nums[nums_position] = num
            nums_position += 1

    while (nums_position < len(nums)):
        nums[nums_position] = 0
        nums_position += 1

    return nums


move_zeroes([0, 1, 0, 3, 12])
# Out:
# [1, 3, 12, 0, 0]

# %% [markdown]
# Intersection of two Lists
# Asked in Companies:
#
# Google
#
# Amazon
#
# Microsoft
#
# Facebook
#
# Description:
# Given two integer arrays nums1 and nums2, return an array of their intersection. Each element in the result must be unique, and you may return the result in any order.

# %%
def intersection(nums1, nums2):
    """
    Function to find the intersection of two integer arrays.
    :param nums1: List[int] -> First array of integers
    :param nums2: List[int] -> Second array of integers
    :return: List[int] -> An array of unique integers present in both arrays
    """
    # TODO: Implement this function
    nums3 = []
    index = 0
    for num in nums1:
        if num in nums2:
            if num not in nums3:
                nums3.insert(index, num)
                index += 1

    return nums3


print(intersection([1, 2, 3], [4, 5, 6]))
print(intersection([1, 2, 2, 1], [2, 2]))
print(intersection([4, 9, 5], [9, 4, 9, 8, 4]))
# Out:
# []
# [2]
# [4, 9]

# %% [markdown]
# Max Consecutive Ones
# Asked in Companies:
#
# Google
#
# Amazon
#
# Microsoft
#
# Facebook

# %%
def find_max_consecutive_ones(nums):
    """
    Function to find the maximum number of consecutive 1's in a binary array.
    :param nums: List[int] -> A binary array where each element is either 0 or 1
    :return: int -> The maximum number of consecutive 1's
    """

    count = 0
    max_count = 0

    for num in nums:
        if num == 1:
            count += 1
            if (max_count < count):
                max_count = count
        else:
            count=0
    return max_count  
            
print(find_max_consecutive_ones([1, 0, 1, 1, 0, 1, 1, 1, 1]))
print(find_max_consecutive_ones([0, 0, 0, 0]))
print(find_max_consecutive_ones([1, 1, 0, 1, 1, 1]))
# Out:
# 4
# 0
# 3
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Maximum Subarray Sum
#
# Description:
#
# Given an array arr of length n, consisting of integers, find the sum of the subarray (including an empty subarray) that has the maximum sum among all possible subarrays.

# %%
def max_subarray_sum(arr):
    """
    Given an array of integers, find the maximum sum of any subarray.

    Parameters:
    arr (List[int]): List of integers.

    Returns:
    int: Maximum sum of any subarray.
    """
    # Implement the function
    if (arr == []):
        return 0
    current_sum = arr[0]
    max_sum = arr[0]
    for i in range(1, len(arr)-1):
        current_sum += arr[i]
        max_sum = max(arr[i], current_sum+arr[i])
        pass

# %% [markdown]
# Problem: Move all EVEN numbers to the front
# Description
#
# Given an array, move all even numbers to the front and odd numbers to the back.
#
# 👉 Order does NOT matter

# %%
def move_even(nums):
    if len(nums) == 0:
        return []
    n = len(nums)
    i = 0
    j = n-1
    temp = 0

    while (i < j):

        if (nums[i] % 2 != 0 and nums[j] % 2 == 0):
            temp = nums[i]
            nums[i] = nums[j]
            nums[j] = temp
            i += 1
            j -= 1
        elif (nums[i] % 2 == 0):
            i += 1
        elif (nums[j] % 2 != 0):
            j -= 1
    return nums


move_even([4, 2, 1, 3])
# Out:
# [4, 2, 1, 3]

# %% [markdown]
# Problem: First Bad Version
# 🧾 Description
#
# You are given n versions of a product:
#
# [1, 2, 3, 4, 5, ..., n]
#
# At some point, a version becomes bad, and all versions after it are also bad.
#
# 👉 There exists a version x such that:
#
# 1 → good
# 2 → good
# ...
# x-1 → good
# x → bad
# x+1 → bad
# ...

# %%
def find_first_bad(nums, first_bad):
    n = len(nums)
    low = 0
    high = n-1
    mid = 0
    answer = -1
    while (low <= high):

        mid = (low+high)//2
        if (first_bad <= nums[mid]):
            answer = mid
            high = mid-1
        else:
            low = mid+1
    return answer

# %% [markdown]
# Bank Account System
# Question 0: Class for Bank Account """ Design a Python class named `BankAccount` to represent bank accounts. Theory: A bank account typically includes attributes such as account number, balance, and account holder name. The class should handle operations such as deposit, withdrawal, and transfer of funds between accounts. Operations: 1. Deposit: Add funds to the account 2. Withdrawal: Subtract funds from the account 3. Transfer: Transfer funds from one account to another Test Cases: Test Case 1: acc1 = BankAccount("John Doe", 1000) acc2 = BankAccount("Jane Smith", 2000) assert acc1.balance == 1000 assert acc2.balance == 2000 acc1.deposit(500) acc2.withdraw(100) acc1.transfer(acc2, 200) assert acc1.balance == 1300 assert acc2.balance == 2300 Test Case 2: acc3 = BankAccount("Alice Johnson", 500) acc4 = BankAccount("Bob Brown", 1500) assert acc3.balance == 500 assert acc4.balance == 1500 acc3.deposit(100) acc4.withdraw(200) acc3.transfer(acc4, 300) assert acc3.balance == 400 assert acc4.balance == 1800 """

# %%
class BankAccount:
    def __init__(self, account_holder, initial_balance):
        self.account_holder = account_holder
        self.initial_balance = initial_balance

    def deposit(self, amount):
        self.initial_balance += amount
        print(f"account balance {self.initial_balance}")

    def withdraw(self, amount):
        if (amount > self.initial_balance):
            print("Teri awkaad se bahar h")
        else:
            self.initial_balance -= amount
            print(f"account balance {self.initial_balance}")
    
        
acc1 = BankAccount("John Doe", 1000)

# %% [markdown]
# Problem: Find First and Last Position of Element in Sorted Array
# 🧾 Problem Statement
#
# You are given a sorted array nums and a target value target.
#
# 👉 Return the starting and ending index of the target in the array.
#
# If the target is not found, return:
#
# [-1, -1]
# 📊 Example 1
# nums = [5, 7, 7, 8, 8, 10]
# target = 8
#
# 👉 Output:
#
# [3, 4]
# 📊 Example 2
# nums = [5, 7, 7, 8, 8, 10]
# target = 6
#
# 👉 Output:
#
# [-1, -1]

# %%
def left_first_Search(lst, item):
    n = len(lst)
    low = 0
    high = n-1
    mid = 0
    answer = -1

    while low <= high:
        mid = (low+high)//2
        if item == lst[mid]:
            answer = mid
            high = mid-1
        elif (item < lst[mid]):
            high = mid-1
        else:
            low = mid+1

    return answer


def right_last_Search(lst, item):
    n = len(lst)
    low = 0
    high = n-1
    mid = 0
    answer = -1

    while low <= high:
        mid = (low+high)//2
        if item == lst[mid]:
            answer = mid
            low = mid+1
        elif (item < lst[mid]):
            high = mid-1
        else:
            low = mid+1

    return answer


nums = [5, 7, 7, 8, 8, 10]
target = 8
print([left_first_Search(nums, target), right_last_Search(nums, target)])

nums = [5, 7, 7, 8, 8, 10]
target = 7
print([left_first_Search(nums, target), right_last_Search(nums, target)])
# Out:
# [3, 4]
# [1, 2]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Problem: Search in Rotated Sorted Array
# 🧾 Problem
#
# You are given a sorted array that is rotated.
#
# 👉 Find the index of target
# 👉 If not found → return -1
#
# 📊 Example
# nums = [4, 5, 6, 7, 0, 1, 2]
# target = 0
#
# 👉 Output:
#
# 4
# 📊 Example 2
# nums = [4, 5, 6, 7, 0, 1, 2]
# target = 3
#
# 👉 Output:
#
# -1
